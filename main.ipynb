# %%
import pandas as pd

df = pd.read_csv("Dataset/synthetic_logs.csv")
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
#
#   complexity
# 0       bert
# 1       bert
# 2       bert
# 3       bert
# 4       bert

# %%
df.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI', 'LegacyCRM'], dtype=object)

# %%
df.log_message.unique()
# Out:
# array(['nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118',
#        'Email service experiencing issues with sending',
#        'Unauthorized access to data was attempted', ...,
#        'nova.metadata.wsgi.server [req-b6d4a270-accb-4c3a-8179-9611e52e1768 - - - - -] 10.11.21.124,10.11.10.1 "GET /openstack/2013-10-17 HTTP/1.1" RCODE  200 len: 157 time: 0.2249990',
#        'Email service affected by failed transmission',
#        'Repeated failed login attempts occurred for user ID 8555'],
#       shape=(2265,), dtype=object)

# %%
df[df.target_label=='System Notification'].sample(10)
# Out:
#             timestamp           source  \
# 988   9/11/2025 22:23    BillingSystem
# 865    2/25/2025 1:40  AnalyticsEngine
# 696    8/25/2025 7:53    ThirdPartyAPI
# 880   6/20/2025 14:45    ThirdPartyAPI
# 714   9/25/2025 23:35    ThirdPartyAPI
# 1276    6/9/2025 0:26         ModernHR
# 1637  2/27/2025 17:24        ModernCRM
# 1332  8/24/2025 10:39    BillingSystem
# 760   1/28/2025 17:31    ThirdPartyAPI
# 183    9/3/2025 23:16    BillingSystem
#
#                                    log_message         target_label complexity
# 988   System reboot initiated by user User427.  System Notification      regex
# 865   System reboot initiated by user User964.  System Notification      regex
# 696       Backup ended at 2025-11-24 19:02:55.  System Notification      regex
# 880       Disk cleanup completed successfully.  System Notification      regex
# 714   System reboot initiated by user User600.  System Notification      regex
# 1276          System updated to version 1.9.6.  System Notification      regex
# 1637            Backup completed successfully.  System Notification      regex
# 1332      Backup ended at 2025-08-22 07:33:55.  System Notification      regex
# 760     Backup started at 2025-02-03 22:33:16.  System Notification      regex
# 183             Backup completed successfully.  System Notification      regex

# %%
df[df.log_message.str.startswith("Backup ended at")]
# Out:
#              timestamp           source                           log_message  \
# 108     3/4/2025 21:15    BillingSystem  Backup ended at 2025-08-08 13:06:23.
# 237    11/10/2025 6:09    BillingSystem  Backup ended at 2025-06-01 06:27:38.
# 264     7/13/2025 9:21    BillingSystem  Backup ended at 2025-11-16 08:17:13.
# 325     6/2/2025 12:18    ThirdPartyAPI  Backup ended at 2025-07-18 17:06:54.
# 367    6/18/2025 12:21    ThirdPartyAPI  Backup ended at 2025-08-18 14:29:26.
# 382    4/27/2025 13:20        ModernCRM  Backup ended at 2025-02-21 07:53:56.
# 407    5/22/2025 18:32        ModernCRM  Backup ended at 2025-08-22 14:11:44.
# 458      2/6/2025 8:00    ThirdPartyAPI  Backup ended at 2025-08-08 14:14:05.
# 518   11/22/2025 13:53  AnalyticsEngine  Backup ended at 2025-04-16 05:59:10.
# 535     3/16/2025 9:05    ThirdPartyAPI  Backup ended at 2025-07-01 14:07:11.
# 1983  11/15/2025 16:09    BillingSystem  Backup ended at 2025-06-08 23:24:35.
# 1990   2/20/2025 11:45         ModernHR  Backup ended at 2025-06-02 10:47:12.
# 2041   10/29/2025 3:05         ModernHR  Backup ended at 2025-11-06 05:28:37.
# 2088    9/25/2025 3:50    BillingSystem  Backup ended at 2025-04-27 00:46:45.
# 2092    7/18/2025 1:08        ModernCRM  Backup ended at 2025-04-30 12:17:31.
# 2127    5/14/2025 5:33  AnalyticsEngine  Backup ended at 2025-11-28 12:48:22.
# 2172    6/8/2025 20:38    BillingSystem  Backup ended at 2025-07-05 07:44:33.
# 2295   8/25/2025 11:35    ThirdPartyAPI  Backup ended at 2025-06-26 20:07:46.
# 2346   8/26/2025 10:04    ThirdPartyAPI  Backup ended at 2025-05-15 10:56:20.
# 2363  10/26/2025 23:44        ModernCRM  Backup ended at 2025-09-19 08:52:02.
# 2395    5/2/2025 14:29    ThirdPartyAPI  Backup ended at 2025-05-06 11:23:16.
#
#              target_label complexity
# 108   System Notification      regex
# 237   System Notification      regex
# 264   System Notification      regex
# 325   System Notification      regex
# 367   System Notification      regex
# 382   System Notification      regex
# 407   System Notification      regex
# 458   System Notification      regex
# 518   System Notification      regex
# 535   System Notification      regex
# 618   System Notification      regex
# 696   System Notification      regex
# 728   System Notification      regex
# 764   System Notification      regex
# 801   System Notification      regex
# 867   System Notification      regex
# 878   System Notification      regex
# 999   System Notification      regex
# 1099  System Notification      regex
# 1134  System Notification      regex
# 1148  System Notification      regex
# 1167  System Notification      regex
# 1255  System Notification      regex
# 1274  System Notification      regex
# 1297  System Notification      regex
# 1322  System Notification      regex
# 1326  System Notification      regex
# 1332  System Notification      regex
# 1512  System Notification      regex
# 1534  System Notification      regex
# 1547  System Notification      regex
# 1564  System Notification      regex
# 1601  System Notification      regex
# 1621  System Notification      regex
# 1680  System Notification      regex
# 1806  System Notification      regex
# 1834  System Notification      regex
# 1872  System Notification      regex
# 1907  System Notification      regex
# 1954  System Notification      regex
# 1961  System Notification      regex
# 1971  System Notification      regex
# 1983  System Notification      regex
# 1990  System Notification      regex
# 2041  System Notification      regex
# 2088  System Notification      regex
# 2092  System Notification      regex
# 2127  System Notification      regex
# 2172  System Notification      regex
# 2295  System Notification      regex
# 2346  System Notification      regex
# 2363  System Notification      regex
# 2395  System Notification      regex

# %%
#Classification Using REGEX

# %%
import re 
def classify_with_regex(log_message):
    regex_patterns = {
        r"User User\d+ logged (in|out)": "User action",
        r"Backup (started|ended) at .*": "System notification",
        r"Backup completed successfully.": "System notification",
        r"System updated to version .*": "System notification",
        r"File .* uploaded successfully by user .*": "System notification",
        r"Disk cleanup  completed successfully.": "System notification",
        r"System reboot initiated by user .*": "System notification",
        r"Account with ID .* created by .*": "User Action"
    }
    for pattern, label in regex_patterns.items():
        if re.search(pattern, log_message):
            return label
    return None

# %%
classify_with_regex('Hey jil jil jil.')
